# %% [markdown]
# # ДЕРЕВА ВИРІШАЛЬНИХ ПРАВИЛ

# %% [markdown]
# 1. Ознайомитися з конспектом лекцій та рекомендованою літературою, а також додатком Б, що містить опис програмного забезпечення для побудови дерев вирішальних правил.
# 2. Сформувати набір даних для обробки та аналізу.
# 3. Використовуючи рекомендоване програмне забезпечення здійснити обробку набору даних з метою побудови дерева
# вирішальних правил.
# 4. Використати побудоване дерево для прийняття рішень на
# конкретному прикладі.

# %%
# import packages 
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix 
from sklearn.externals.six import StringIO
from IPython.display import Image 
from pydot import graph_from_dot_data 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Данные взяты с kaggel.com : https://www.kaggle.com/andrewmvd/heart-failure-clinical-data
# Цель работы построить дерево принятия решений для выяснения болен человек или нет 
# load dataset
df_heart = pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
df_heart.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %% [markdown]
# Интерпретация данных \
# 1) sex: Male=1 Female=0 \
# 2) diabets: No=0 Yes=1 \
# 3) anaemia: No=0 Yes=1 \
# 4) high_blood_pressure: No=0 Yes=1 \
# 5) smoking: No=0 Yes=1 \
# 6) DEATH_EVENT: No=0 Yes=1

# %%
# анализ данных 
df_heart['DEATH_EVENT'].value_counts().plot.bar()

# %%
# данные чистые и в нужном нам формате для работы
# классифицировать в нашем случае будем по DEATH_EVENT
df_heart.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
X = df_heart.drop(['DEATH_EVENT'], axis=1).copy()
X.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time
# 0        0     4
# 1        0     6
# 2        1     7
# 3        0     7
# ...

# %%
y = df_heart['DEATH_EVENT'].copy()
# создадим две колонки (здоровый больной)
test= pd.DataFrame()
y.loc[df_heart['DEATH_EVENT']==0]=1
y.loc[df_heart['DEATH_EVENT']==1]=0
y.loc[df_heart['DEATH_EVENT']==1]=1
y.loc[df_heart['DEATH_EVENT']==0]=0
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 299, dtype: int64

# %%
# как выяснилось time - не нужен (это время в которое пациент умер) для выяснения болен 
# человек или нет не играет роли 
X = X.drop(['time'], axis=1)
X
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
# разделение данных для дальнейшей проверки 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
columns_n = ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'serum_sodium', 'sex', 'smoking']

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
dot_data = StringIO()
export_graphviz(dt, out_file = dot_data, feature_names = columns_n)
(graph, ) = graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
#  проверка на тестовых данных 
y_pred = dt.predict(X_test)

# %%
df_predict = pd.DataFrame(columns=['result'], data=y_pred)

# %%
df_predict
# Out:
#     result
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
# ..     ...
# 70       0
# 71       0
# 72       0
# 73       0
# 74       0
#
# [75 rows x 1 columns]

# %%
y_test.drop('prediction', inplace=True)

# %%
y_test = y_test.reset_index()
y_test.drop('index',axis =1, inplace = True)

# %%
y_test['predict_result'] = df_predict['result']

# %%
y_test.loc[y_test['DEATH_EVENT']==y_test['predict_result']].count()
# Out:
# DEATH_EVENT       55
# predict_result    55
# dtype: int64

# %% [markdown]
# Вывод: \
# Было построенно дерево принятия решений на основе датасет из открытого источника данных. \
# Построенное дерево проверенно на тестовом сете (предварительно начальный датасет делили на тренировочный и тестовый)  \
# На тестовом сете получили 73.(3) % результат предсказания
# https://www.machinelearningmastery.ru/decision-tree-in-python-b433ae57fb93/
